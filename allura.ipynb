# %% [markdown]
# <a href="https://colab.research.google.com/github/miguel-web1/Challenge_Data_SCIENCE/blob/main/allura.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### Importación de datos

# %%
import pandas as pd

url = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science-latam/refs/heads/main/base-de-datos-challenge1-latam/tienda_1%20.csv"
url2 = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science-latam/refs/heads/main/base-de-datos-challenge1-latam/tienda_2.csv"
url3 = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science-latam/refs/heads/main/base-de-datos-challenge1-latam/tienda_3.csv"
url4 = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science-latam/refs/heads/main/base-de-datos-challenge1-latam/tienda_4.csv"

tienda = pd.read_csv(url)
tienda2 = pd.read_csv(url2)
tienda3 = pd.read_csv(url3)
tienda4 = pd.read_csv(url4)

tienda.head()
# Out:
#             Producto Categoría del Producto    Precio  Costo de envío  \
# 0  Asistente virtual           Electrónicos  164300.0          6900.0
# 1    Mesa de comedor                Muebles  192300.0          8400.0
# 2      Juego de mesa               Juguetes  209600.0         15900.0
# 3         Microondas      Electrodomésticos  757500.0         41000.0
# 4   Silla de oficina                Muebles  335200.0         20200.0
#
#   Fecha de Compra         Vendedor Lugar de Compra  Calificación  \
# 0      16/01/2021      Pedro Gomez          Bogotá             4
# 1      18/05/2022  Beatriz Morales        Medellín             1
# 2      15/03/2021   Juan Fernandez       Cartagena             1
# 3      03/05/2022   Juan Fernandez            Cali             4
# 4      07/11/2020    Maria Alfonso        Medellín             5
#
#        Método de pago  Cantidad de cuotas       lat       lon
# 0  Tarjeta de crédito                   8   4.60971 -74.08175
# ...

# %%
import pandas as pd

url = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science-latam/refs/heads/main/base-de-datos-challenge1-latam/tienda_1%20.csv"
url2 = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science-latam/refs/heads/main/base-de-datos-challenge1-latam/tienda_2.csv"
url3 = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science-latam/refs/heads/main/base-de-datos-challenge1-latam/tienda_3.csv"
url4 = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science-latam/refs/heads/main/base-de-datos-challenge1-latam/tienda_4.csv"

tienda = pd.read_csv(url)
tienda2 = pd.read_csv(url2)
tienda3 = pd.read_csv(url3)
tienda4 = pd.read_csv(url4)

ingreso_tienda1 = tienda["Precio"].sum()
ingreso_tienda2 = tienda2["Precio"].sum()
ingreso_tienda3 = tienda3["Precio"].sum()
ingreso_tienda4 = tienda4["Precio"].sum()

print(f"Ingreso Tienda 1: {ingreso_tienda1}")
print(f"Ingreso Tienda 2: {ingreso_tienda2}")
print(f"Ingreso Tienda 3: {ingreso_tienda3}")
print(f"Ingreso Tienda 4: {ingreso_tienda4}")
# Out:
# Ingreso Tienda 1: 1150880400.0
# Ingreso Tienda 2: 1116343500.0
# Ingreso Tienda 3: 1098019600.0
# Ingreso Tienda 4: 1038375700.0

# %% [markdown]
# #1. Análisis de facturación

# %% [markdown]
# # 2. Ventas por categoría

# %%
import pandas as pd

url = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science-latam/refs/heads/main/base-de-datos-challenge1-latam/tienda_1%20.csv"
url2 = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science-latam/refs/heads/main/base-de-datos-challenge1-latam/tienda_2.csv"
url3 = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science-latam/refs/heads/main/base-de-datos-challenge1-latam/tienda_3.csv"
url4 = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science-latam/refs/heads/main/base-de-datos-challenge1-latam/tienda_4.csv"

tienda = pd.read_csv(url)
tienda2 = pd.read_csv(url2)
tienda3 = pd.read_csv(url3)
tienda4 = pd.read_csv(url4)

Categoria_tienda1 = tienda["Categoría del Producto"].value_counts()
Categoria_tienda2 = tienda2["Categoría del Producto"].value_counts()
Categoria_tienda3 = tienda3["Categoría del Producto"].value_counts()
Categoria_tienda4 = tienda4["Categoría del Producto"].value_counts()

print(f"categoria tienda 1: {Categoria_tienda1}")
print(f"categoria tienda 2: {Categoria_tienda2}")
print(f"categoria tienda 3: {Categoria_tienda3}")
print(f"categoria tienda 4: {Categoria_tienda4}")
# Out:
# categoria tienda 1: Categoría del Producto
# Muebles                    465
# Electrónicos               448
# Juguetes                   324
# Electrodomésticos          312
# Deportes y diversión       284
# Instrumentos musicales     182
# Libros                     173
# Artículos para el hogar    171
# Name: count, dtype: int64
# categoria tienda 2: Categoría del Producto
# Muebles                    442
# Electrónicos               422
# Juguetes                   313
# Electrodomésticos          305
# Deportes y diversión       275
# Instrumentos musicales     224
# Libros                     197
# Artículos para el hogar    181
# Name: count, dtype: int64
# categoria tienda 3: Categoría del Producto
# Muebles                    499
# Electrónicos               451
# Juguetes                   315
# Electrodomésticos          278
# Deportes y diversión       277
# Libros                     185
# Instrumentos musicales     177
# Artículos para el hogar    177
# ...

# %% [markdown]
# # 3. Calificación promedio de la tienda

# %%
import pandas as pd

url = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science-latam/refs/heads/main/base-de-datos-challenge1-latam/tienda_1%20.csv"
url2 = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science-latam/refs/heads/main/base-de-datos-challenge1-latam/tienda_2.csv"
url3 = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science-latam/refs/heads/main/base-de-datos-challenge1-latam/tienda_3.csv"
url4 = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science-latam/refs/heads/main/base-de-datos-challenge1-latam/tienda_4.csv"

tienda = pd.read_csv(url)
tienda2 = pd.read_csv(url2)
tienda3 = pd.read_csv(url3)
tienda4 = pd.read_csv(url4)

Promedio_tienda1 = tienda["Calificación"].mean()
Promedio_tienda2 = tienda2["Calificación"].mean()
Promedio_tienda3 = tienda3["Calificación"].mean()
Promedio_tienda4 = tienda4["Calificación"].mean()

print(f"Calificación promedio Tienda 1: {Promedio_tienda1}")
print(f"Calificación promedio Tienda 2: {Promedio_tienda2}")
print(f"Calificación promedio Tienda 3: {Promedio_tienda3}")
print(f"Calificación promedio Tienda 4: {Promedio_tienda4}")
# Out:
# Calificación promedio Tienda 1: 3.976685036032217
# Calificación promedio Tienda 2: 4.037303942348453
# Calificación promedio Tienda 3: 4.048325561678677
# Calificación promedio Tienda 4: 3.9957591178965224

# %% [markdown]
# # 4. Productos más y menos vendidos

# %%
import pandas as pd

url = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science-latam/refs/heads/main/base-de-datos-challenge1-latam/tienda_1%20.csv"
url2 = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science-latam/refs/heads/main/base-de-datos-challenge1-latam/tienda_2.csv"
url3 = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science-latam/refs/heads/main/base-de-datos-challenge1-latam/tienda_3.csv"
url4 = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science-latam/refs/heads/main/base-de-datos-challenge1-latam/tienda_4.csv"

tienda = pd.read_csv(url)
tienda2 = pd.read_csv(url2)
tienda3 = pd.read_csv(url3)
tienda4 = pd.read_csv(url4)

venta_producT1 = tienda["Producto"].value_counts()
venta_producT2 = tienda2["Producto"].value_counts()
venta_producT3 = tienda3["Producto"].value_counts()
venta_producT4 = tienda4["Producto"].value_counts()

print("TIENDA 1:  ")
print(f"Mas vendido: {venta_producT1.head(1)}")
print(f"Menos vendido: {venta_producT1.tail(1)}")

print("TIENDA 2:  ")
print(f"Mas vendido: {venta_producT2.head(1)}")
print(f"Menos vendido: {venta_producT2.tail(1)}")

print("TIENDA 3:  ")
print(f"Mas vendido: {venta_producT3.head(1)}")
print(f"Menos vendido: {venta_producT3.tail(1)}")

print("TIENDA 4:  ")
print(f"Mas vendido: {venta_producT4.head(1)}")
print(f"Menos vendido: {venta_producT4.tail(1)}")
# Out:
# TIENDA 1:
# Mas vendido: Producto
# Microondas    60
# Name: count, dtype: int64
# Menos vendido: Producto
# Celular ABXY    33
# Name: count, dtype: int64
# TIENDA 2:
# Mas vendido: Producto
# Iniciando en programación    65
# Name: count, dtype: int64
# Menos vendido: Producto
# Juego de mesa    32
# Name: count, dtype: int64
# TIENDA 3:
# Mas vendido: Producto
# Kit de bancas    57
# Name: count, dtype: int64
# Menos vendido: Producto
# Bloques de construcción    35
# Name: count, dtype: int64
# TIENDA 4:
# Mas vendido: Producto
# Cama box    62
# Name: count, dtype: int64
# Menos vendido: Producto
# Guitarra eléctrica    33
# Name: count, dtype: int64

# %% [markdown]
# # 5. Envío promedio por tienda

# %%
import pandas as pd

url = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science-latam/refs/heads/main/base-de-datos-challenge1-latam/tienda_1%20.csv"
url2 = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science-latam/refs/heads/main/base-de-datos-challenge1-latam/tienda_2.csv"
url3 = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science-latam/refs/heads/main/base-de-datos-challenge1-latam/tienda_3.csv"
url4 = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science-latam/refs/heads/main/base-de-datos-challenge1-latam/tienda_4.csv"

tienda = pd.read_csv(url)
tienda2 = pd.read_csv(url2)
tienda3 = pd.read_csv(url3)
tienda4 = pd.read_csv(url4)

envio_t1 = tienda["Costo de envío"].mean()
envio_t2 = tienda2["Costo de envío"].mean()
envio_t3 = tienda3["Costo de envío"].mean()
envio_t4 = tienda4["Costo de envío"].mean()

print(f"Costo envío promedio Tienda 1: {envio_t1:.2f}")
print(f"Costo envío promedio Tienda 2: {envio_t2:.2f}")
print(f"Costo envío promedio Tienda 3: {envio_t3:.2f}")
print(f"Costo envío promedio Tienda 4: {envio_t4:.2f}")
# Out:
# Costo envío promedio Tienda 1: 26018.61
# Costo envío promedio Tienda 2: 25216.24
# Costo envío promedio Tienda 3: 24805.68
# Costo envío promedio Tienda 4: 23459.46

# %% [markdown]
# ANALISIS FINAL

# %%
import matplotlib.pyplot as plt

ingresos = [
    tienda["Precio"].sum(),
    tienda2["Precio"].sum(),
    tienda3["Precio"].sum(),
    tienda4["Precio"].sum()
]

tiendas = ["Tienda 1", "Tienda 2", "Tienda 3", "Tienda 4"]

plt.figure()
plt.bar(tiendas, ingresos)
plt.title("Ingresos totales por tienda")
plt.xlabel("Tienda")
plt.ylabel("Ingreso total")
plt.show()

# %%
import matplotlib.pyplot as plt

categorias = tienda["Categoría del Producto"].value_counts().head(5)

plt.figure()
categorias.plot(kind="bar")
plt.title("Top 5 categorías más vendidas - Tienda 1")
plt.xlabel("Categoría")
plt.ylabel("Cantidad de ventas")
plt.show()

# %%
calificaciones = [
    tienda["Calificación"].mean(),
    tienda2["Calificación"].mean(),
    tienda3["Calificación"].mean(),
    tienda4["Calificación"].mean()
]

plt.figure()
plt.plot(tiendas, calificaciones, marker="o")
plt.title("Calificación promedio por tienda")
plt.xlabel("Tienda")
plt.ylabel("Calificación promedio")
plt.show()

# %% [markdown]
# El presente informe tiene como finalidad analizar el desempeño de cuatro tiendas con el objetivo de determinar a qué tienda debe vender el Sr. Juan. Para ello, se evaluaron indicadores clave como ingresos totales, categorías más vendidas, calificaciones promedio de los clientes, productos más y menos vendidos y el costo de envío promedio, apoyados en análisis de datos y visualizaciones gráficas.
#
# Metodología
#
# Se utilizaron conjuntos de datos correspondientes a cuatro tiendas, los cuales fueron analizados mediante la librería Pandas en Python. Posteriormente, se generaron visualizaciones con Matplotlib para facilitar la interpretación de los resultados.
#
# Resultados
# 3.1 Ingresos totales
#
# Tienda 1: 1,150,880,400
#
# Tienda 2: 1,116,343,500
#
# Tienda 3: 1,098,019,600
#
# Tienda 4: 1,038,375,700
#
# La Tienda 1 presenta el mayor ingreso total, lo que evidencia un mejor desempeño económico.
#
# 3.2 Categorías más vendidas
#
# En todas las tiendas, las categorías con mayor volumen de ventas fueron:
#
# Muebles
#
# Electrónicos
#
# Juguetes
#
# La Tienda 1 mantiene una alta demanda constante en estas categorías.
#
# 3.3 Calificación promedio de los clientes
#
# Tienda 1: 3.98
#
# Tienda 2: 4.04
#
# Tienda 3: 4.05
#
# Tienda 4: 4.00
#
# Aunque la Tienda 3 posee la mayor calificación, la diferencia con la Tienda 1 es mínima.
#
# 3.4 Productos más y menos vendidos
#
# Tienda 1:
#
# Más vendido: Microondas (60)
#
# Menos vendido: Celular ABXY (33)
#
# Tienda 2:
#
# Más vendido: Iniciando en programación (65)
#
# Menos vendido: Juego de mesa (32)
#
# Tienda 3:
#
# Más vendido: Kit de bancas (57)
#
# Menos vendido: Bloques de construcción (35)
#
# Tienda 4:
#
# Más vendido: Cama box (62)
#
# Menos vendido: Guitarra eléctrica (33)
#
# 3.5 Costo de envío promedio
#
# Tienda 1: 26,018.61
#
# Tienda 2: 25,216.24
#
# Tienda 3: 24,805.68
#
# Tienda 4: 23,459.46
#
# El mayor costo de envío corresponde a la Tienda 1, sin afectar directamente los ingresos, ya que es asumido por el cliente.
#
# Conclusión
#
# Tras analizar todos los indicadores, se concluye que la Tienda 1 es la mejor opción para que el Sr. Juan realice sus ventas, debido a que presenta el mayor ingreso total, una alta demanda en las categorías principales, productos de alta rotación y una satisfacción del cliente aceptable.
# A pesar de no tener la calificación más alta ni el menor costo de envío, su desempeño económico superior la convierte en la opción más rentable.

# %%
import matplotlib.pyplot as plt

plt.figure()
plt.scatter(tienda["lon"], tienda["lat"], alpha=0.3)
plt.title("Distribución geográfica de ventas - Tienda 1")
plt.xlabel("Longitud")
plt.ylabel("Latitud")
plt.show()

# %%
plt.figure()
plt.scatter(tienda["lon"], tienda["lat"], alpha=0.3, label="Tienda 1")
plt.scatter(tienda2["lon"], tienda2["lat"], alpha=0.3, label="Tienda 2")
plt.legend()
plt.title("Comparación geográfica de ventas")
plt.xlabel("Longitud")
plt.ylabel("Latitud")
plt.show()

# %% [markdown]
# Al analizar las coordenadas geográficas de las ventas, se observa que las compras no se distribuyen de manera uniforme, sino que se concentran en determinadas zonas geográficas. La Tienda 1 presenta una mayor densidad de ventas en comparación con las demás, lo cual es coherente con su mayor nivel de ingresos. No se identifican regiones con bajo rendimiento extremo, lo que sugiere una cobertura geográfica estable. Estos patrones indican que la ubicación geográfica influye en el volumen de ventas, aunque no representa un factor determinante frente a los ingresos totales.
